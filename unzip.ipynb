# %%
# !unzip .zip -d

# %%
import os
path_to_directory="/content/drive/MyDrive/Takeout_Project/input/"
ip="/content/drive/MyDrive/Takeout/"
for i in os.listdir(ip):
  # !unzip $ip$i -d $path_to_directory
# Out:
# Archive:  /content/drive/MyDrive/Takeout/takeout-20220115T084309Z-001.zip
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Collection Point/Collection Point.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Profile/Profile.json
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Addresses/Addresses.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Loyalty/Loyalty.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Merchant Reviews/Merchant Reviews.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Orders/Orders.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Product Reviews/Product Reviews.txt
#   inflating: /content/drive/MyDrive/Takeout_Project/input/Takeout/Google Shopping/Order Preferred Contact Emails/Order Preferred Contact Emails.txt
# ...
